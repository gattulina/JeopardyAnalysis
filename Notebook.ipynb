# %% [markdown]
# # 1.Enviorenment

# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt

# helpful character encoding modul
import chardet

# pip3.10 install openpyxl

# %% [markdown]
# # 2.Importing data

# %%
df = pd.read_csv('/Users/luciana/Desktop/Python data analysis/JEOPARDY_CSV.csv', sep= ";")
df.head(5)
# Out:
#    Show Number    Air Date      Round                Category  Value  \
# 0         3751  18/12/2000  Jeopardy!  ROYAL FEMALE NICKNAMES  $100
# 1         3751  18/12/2000  Jeopardy!       TV ACTORS & ROLES  $100
# 2         3751  18/12/2000  Jeopardy!        TRAVEL & TOURISM  $100
# 3         3751  18/12/2000  Jeopardy!                "I" LADS  $100
# 4         3751  18/12/2000  Jeopardy!               FOREWORDS  $100
#
#                                             Question             Answer
# 0  Prime Minister Tony Blair dubbed her "The Peop...     Princess Diana
# 1  Once Tommy Mullaney on "L.A. Law", John Spence...      The West Wing
# 2  The Cinderella Castle Mystery Tour is a highli...              Tokyo
# 3  This punk rock hitmaker heard here has had num...         Billy Idol
# 4  "Conrad begins (and ends) Marlow's journey... ...  Heart of Darkness

# %% [markdown]
# ## Checking correct encoding

# %%
# checking correct encoding 
# look at the first ten thousand bytes to guess the character encoding
with open ('/Users/luciana/Desktop/Python data analysis/JEOPARDY_CSV.csv', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))

# check what the character encoding might be
print(result)

#100% encoding UTF 8 SIG which is the default one
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# ## Getting to know the dataset

# %%
df.sample(5)
# Out:
#        Show Number    Air Date             Round            Category  Value  \
# 75629         2870  07/02/1997   Final Jeopardy!  HISTORIC GEOGRAPHY   None
# 18965         3164  07/05/1998         Jeopardy!  "N" THE DICTIONARY  $200
# 27581         1984  01/04/1993         Jeopardy!       STATE MOTTOES  $300
# 52235         3899  12/07/2001  Double Jeopardy!                 ABC  $800
# 47907         3047  25/11/1997         Jeopardy!      WOMEN AND SONG  $500
#
#                                                 Question               Answer
# 75629  The former kingdom of Saxony is now located in...              Germany
# 18965  This term for a between-meal snack comes from ...                 Nosh
# 27581  This state motto of Virginia translates to "Th...  Sic semper tyrannis
# 52235  This adjective has been used to describe the c...              acerbic
# 47907  In 1997 this singer of "You Were Meant For Me"...                Jewel

# %%
df.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
print("Dataframe Total Features and columns")
df.shape
#Categorical and numerical features
# Out:
# Dataframe Total Features and columns
# (90900, 7)

# %%
df.dtypes
#Airdate should be stored as a date 
#Value should be stored as INT
# Out:
# Show Number     int64
#  Air Date      object
#  Round         object
#  Category      object
#  Value         object
#  Question      object
#  Answer        object
# dtype: object

# %% [markdown]
# # 3.Data cleaning

# %% [markdown]
# ## 3.1 General data preprocessing

# %%
#when calling columns I found errors, so Ive noticed there are spaces on their names.
#So I rename them.
df=df.rename(columns = {'Show Number': 'Show_Number', ' Air Date': 'Air_Date' , ' Round':'Round', ' Category':'Category', 
            ' Value': 'Value', ' Question': 'Question', ' Answer':'Answer'})

# %% [markdown]
# ## 3.2 Categorical data preprocessing

# %% [markdown]
# ### Round

# %%
#Fast checking the correct spelling of values in each column
df['Round'].unique()
#working great
# Out:
# array(['Jeopardy!', 'Double Jeopardy!', 'Final Jeopardy!', 'Tiebreaker'],
#       dtype=object)

# %% [markdown]
# ### Category

# %%
df['Category'].unique()
# Out:
# array(['ROYAL FEMALE NICKNAMES', 'TV ACTORS & ROLES', 'TRAVEL & TOURISM',
#        ..., 'TAXI', '"CAB"', 'MAJOR LEAGUE BASEBALL TEAM NAMES'],
#       dtype=object)

# %%
#Library to remove special characters
import re

# put the special characters in a list
special_char_general = ['"','$' , '*', '/', '(', ')', ':', '\n', 'â€œeasyâ€']

special_char_escaped_general = list(map(re.escape, special_char_general))

# %%
#deleting special characters
df['Category'] = df['Category'] .replace(special_char_escaped_general, '', regex=True)

# %%
#checking on the corrections made on excel
df2=df[df["Category"] == 'Unknown'] 
print(df2)
# Out:
#        Show_Number    Air_Date             Round Category    Value  \
# 16700         3704  12/10/2000         Jeopardy!  Unknown    $100
# 16706         3704  12/10/2000         Jeopardy!  Unknown    $200
# 16712         3704  12/10/2000         Jeopardy!  Unknown    $300
# 16718         3704  12/10/2000         Jeopardy!  Unknown    $400
# 16724         3704  12/10/2000         Jeopardy!  Unknown    $500
# 19185         3783  31/01/2001   Final Jeopardy!  Unknown     None
# 23992         2891  10/03/1997         Jeopardy!  Unknown    $100
# 23998         2891  10/03/1997         Jeopardy!  Unknown    $200
# 24004         2891  10/03/1997         Jeopardy!  Unknown    $300
# 24010         2891  10/03/1997         Jeopardy!  Unknown    $400
# 24016         2891  10/03/1997         Jeopardy!  Unknown    $500
# 34454         4263  26/02/2003  Double Jeopardy!  Unknown    $400
# 34460         4263  26/02/2003  Double Jeopardy!  Unknown    $800
# ...

# %% [markdown]
# ### Question

# %%
#df2=df[df["Answer"] == 'Dwight D. Eisenhower'] 
#print(df2)

# %%
# Specific correction cases
#not working because I couldn't split the text from the rows to detect HTML code
special_char_forQuestions = ['<a href="']

special_char_escaped_forQuestions = list(map(re.escape, special_char_forQuestions))

# Other examples
#df[df['Courses'].str.contains("Spark")]
#df[df['Courses'].str.lower().str.contains("spark")]
#df[df['Courses'].str.startswith("P")]

# %%
#Checking on strange Questions that appeared on Power BI
df2=df[df["Question"] == 'AR'] 
print(df2)
# Out:
#        Show_Number    Air_Date             Round  \
# 28731         4417  18/11/2003  Double Jeopardy!
# 34947         3449  09/09/1999  Double Jeopardy!
# 60106         3333  17/02/1999         Jeopardy!
#
#                             Category  Value Question    Answer
# 28731  AMERICAN POSTAL ABBREVIATIONS  $800        AR  Arkansas
# 34947      U.S. POSTAL ABBREVIATIONS  $800        AR  Arkansas
# 60106  AMERICAN POSTAL ABBREVIATIONS  $300        AR  Arkansas

# %%
df2=df[df["Question"] == '"Charlie Hustle"'] 
print(df2)
# Out:
#        Show_Number    Air_Date      Round            Category  Value  \
# 21110         3478  20/10/1999  Jeopardy!  BASEBALL NICKNAMES  $100
# 53792         2904  27/03/1997  Jeopardy!  BASEBALL NICKNAMES  $100
# 61763         4369  11/09/2003  Jeopardy!  BASEBALL NICKNAMES  $200
#
#                Question     Answer
# 21110  "Charlie Hustle"  Pete Rose
# 53792  "Charlie Hustle"  Pete Rose
# 61763  "Charlie Hustle"  Pete Rose

# %%
#deleting special characters
df['Question'] = df['Question'] .replace(special_char_escaped_general, '', regex=True)

#checking correct implementation
df2=df[df["Question"] == '"Charlie Hustle"'] 
print(df2)
# Out:
# Empty DataFrame
# Columns: [Show_Number, Air_Date, Round, Category, Value, Question, Answer]
# Index: []

# %% [markdown]
# ### Answer

# %% [markdown]
# ## 3.3 Numerical data preprocessing

# %% [markdown]
# ### Show_Number

# %%
shown = df['Show_Number'].unique()
shown
#too many values, trying with sth else
# Out:
# array([3751, 3673, 2825, ..., 3038, 2046, 3940])

# %%
df['Show_Number'].describe()
# Out:
# count    90900.000000
# mean      3467.519912
# std        535.676564
# min       1932.000000
# 25%       3080.000000
# 50%       3468.000000
# 75%       3855.250000
# max       4417.000000
# Name: Show_Number, dtype: float64

# %% [markdown]
# ### Value

# %%
values = df['Value'].unique()
values
#giving a quick look to values, Ive found a String.
# Out:
# array(['$100 ', '$200 ', '$300 ', '$400 ', '$500 ', '$600 ', '$800 ',
#        '$1.000 ', '$2.000 ', 'None', '$1.500 ', '$1.100 ', '$1.800 ',
#        '$1.600 ', '$1.200 ', '$3.000 ', '$6.800 ', '$4.000 ', '$1.400 ',
#        '$700 ', '$2.500 ', '$2.400 ', '$2.600 ', '$5.000 ', '$3.200 ',
#        '$3.300 ', '$1.900 ', '$7.000 ', '$5.400 ', '$900 ', '$4.400 ',
#        '$2.900 ', '$10.800 ', '$2.300 ', '$750 ', '$1.700 ', '$9.000 ',
#        '$2.200 ', '$2.100 ', '$6.100 ', '$3.500 ', '$3.400 ', '$1.300 ',
#        '$4.700 ', '$2.001 ', '$1.263 ', '$4.637 ', '$3.800 ', '$3.700 ',
#        '$4.500 ', '$3.600 ', '$14.000 ', '$6.000 ', '$6.400 ', '$10.000 ',
#        '$250 ', '$7.200 ', '$6.600 ', '$9.500 ', '$5.600 ', '$2.700 ',
#        '$10.400 ', '$5.200 ', '$2.800 ', '$4.600 ', '$6.700 ', '$4.300 ',
#        '$1.407 ', '$3.100 ', '$13.000 ', '$11.600 ', '$7.800 ', '$5 ',
#        '$1.809 ', '$11.000 ', '$1.000.000 ', '$3.499 ', '$1.111 ',
# ...

# %%
#replacing the string with int to make possible making calcs in future
df['Value']=df['Value'].replace('None', '0')

# %%
special_char_forValues = ['$', '.']

special_char_escaped_forValues = list(map(re.escape, special_char_forValues))

# %%
#deleting special characters
df['Value'] = df['Value'] .replace(special_char_escaped_forValues, '', regex=True)

#checking correct implementation
values = df['Value'].unique()
values
# Out:
# array(['100 ', '200 ', '300 ', '400 ', '500 ', '600 ', '800 ', '1000 ',
#        '2000 ', '0', '1500 ', '1100 ', '1800 ', '1600 ', '1200 ', '3000 ',
#        '6800 ', '4000 ', '1400 ', '700 ', '2500 ', '2400 ', '2600 ',
#        '5000 ', '3200 ', '3300 ', '1900 ', '7000 ', '5400 ', '900 ',
#        '4400 ', '2900 ', '10800 ', '2300 ', '750 ', '1700 ', '9000 ',
#        '2200 ', '2100 ', '6100 ', '3500 ', '3400 ', '1300 ', '4700 ',
#        '2001 ', '1263 ', '4637 ', '3800 ', '3700 ', '4500 ', '3600 ',
#        '14000 ', '6000 ', '6400 ', '10000 ', '250 ', '7200 ', '6600 ',
#        '9500 ', '5600 ', '2700 ', '10400 ', '5200 ', '2800 ', '4600 ',
#        '6700 ', '4300 ', '1407 ', '3100 ', '13000 ', '11600 ', '7800 ',
#        '5 ', '1809 ', '11000 ', '1000000 ', '3499 ', '1111 ', '8600 ',
#        '601 ', '4800 ', '2811 ', '7400 ', '20 ', '1810 ', '1512 ',
#        '4200 ', '585 ', '1534 ', '8000 ', '350 ', '7500 ', '5500 ',
#        '5800 '], dtype=object)

# %%
df['Value'].dtype
#still an object
# Out:
# dtype('O')

# %%
df['Value'] =  df['Value'].astype(int)

# %%
df['Value'].describe()
#GREAT!
# Out:
# count      90900.000000
# mean         564.185545
# std         3351.008071
# min            0.000000
# 25%          200.000000
# 50%          400.000000
# 75%          800.000000
# max      1000000.000000
# Name: Value, dtype: float64

# %% [markdown]
# ## 3.4 Parsing dates

# %%
df['Air_Date'].head(5)
# Out:
# 0    18/12/2000
# 1    18/12/2000
# 2    18/12/2000
# 3    18/12/2000
# 4    18/12/2000
# Name: Air_Date, dtype: object

# %%
#First, I tried to convert the column in a data field but it shows me an error.
df['Air_Date_parsed'] = pd.to_datetime(df['Air_Date'], format = "%Y-%m-%d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [32], line 2
# ...

# %%
#Trying to locate the error, I pick up the show number to understand the correct format of the errorDate 
# (YYYYmmdd or YYYYddmm)
df.loc[df['Air_Date'] == '1/12/20001']
# Out:
#        Show_Number    Air_Date      Round                      Category  \
# 42760         3770  1/12/20001  Jeopardy!               FASHION FORWARD
# 42761         3770  1/12/20001  Jeopardy!              EUROPEAN HISTORY
# 42762         3770  1/12/20001  Jeopardy!               COMIC STRIPPERS
# 42763         3770  1/12/20001  Jeopardy!  YES SIR, THAT'S MY SCIENTIST
# 42764         3770  1/12/20001  Jeopardy!                    NEW MEXICO
# 42765         3770  1/12/20001  Jeopardy!                   POMP IT UP!
# 42766         3770  1/12/20001  Jeopardy!               FASHION FORWARD
# 42767         3770  1/12/20001  Jeopardy!              EUROPEAN HISTORY
# 42768         3770  1/12/20001  Jeopardy!               COMIC STRIPPERS
# 42769         3770  1/12/20001  Jeopardy!  YES SIR, THAT'S MY SCIENTIST
# 42770         3770  1/12/20001  Jeopardy!                    NEW MEXICO
# 42771         3770  1/12/20001  Jeopardy!                   POMP IT UP!
# ...

# %%
#uniqueValues = (df['Show_Number','Air_Date'])
#print(uniqueValues)
#dfUnique = pd.DataFrame(uniqueValues)
#print(dfUnique)
#dfUnique.loc[(dfUnique['Show_Number'] >= 3750) & (dfUnique['Show_Number'] <= 3800)]
error2001 = df.loc[(df['Show_Number'] >= 3769) & (df['Show_Number'] <= 3771)]
error2001 .sort_values('Show_Number', ascending=False)

#The best option would had been creating a new df matching unique values of show n and date. But since it takes me
#I did the fast way. Is no hard to notice that the previous show was in 15th jan, and the following one 11th. 
#This makes me realize that the show error date probably is '2001-01-12'
# Out:
#        Show_Number    Air_Date             Round                 Category  \
# 14255         3771  15/01/2001         Jeopardy!           OKLAHOMA IS OK
# 14286         3771  15/01/2001  Double Jeopardy!                THE BIBLE
# 14288         3771  15/01/2001  Double Jeopardy!              GET TO WORK
# 14289         3771  15/01/2001  Double Jeopardy!     BEGINS & ENDS WITH N
# 14290         3771  15/01/2001  Double Jeopardy!  MARTIN LUTHER KING, JR.
# ...            ...         ...               ...                      ...
# 83537         3769  11/01/2001         Jeopardy!       NEW YORK, NEW YORK
# 83538         3769  11/01/2001         Jeopardy!     ALL THE KING'S SONGS
# 83539         3769  11/01/2001         Jeopardy!               AMPHIBIANS
# 83540         3769  11/01/2001         Jeopardy!       AUSSIE ODDS & ENDS
# 83573         3769  11/01/2001   Final Jeopardy!          WOMEN IN SPORTS
#
#        Value                                           Question  \
# ...

# %%
#deleting the 20001 error
df['Air_Date'] = df['Air_Date'] .replace('1/12/20001', '1/12/2001')

# %%
#re running the dates parsed 
#convert datetime column to just date
df['Air_Date'] = pd.to_datetime(df['Air_Date']).dt.normalize()

df['Air_Date'].head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/12/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/06/1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %% [markdown]
# ## 3.5 Dealing with NAs

# %%
print(df.isnull().sum())
#Is this value missing becuase it wasn't recorded or becuase it dosen't exist?
# Out:
# Show_Number    0
# Air_Date       0
# Round          0
# Category       0
# Value          0
# Question       0
# Answer         1
# dtype: int64

# %%
df[df.isna().any(axis=1)]
#Because is just one field in 90thousand rows, Im gonna keep it.
# Out:
#        Show_Number   Air_Date      Round     Category  Value  \
# 38264         4346 2003-06-23  Jeopardy!  GOING NSANE    200
#
#                          Question Answer
# 38264  It often precedes and void    NaN

# %% [markdown]
# # 4. Analysing the results of the cleaning

# %%
df.sample(5)
# Out:
#        Show_Number   Air_Date             Round            Category  Value  \
# 18334         3004 1997-09-25  Double Jeopardy!   WOODY ALLEN FILMS    400
# 21052         3753 2000-12-20         Jeopardy!           THE 1980s    100
# 55007         3524 1999-12-23  Double Jeopardy!            LOW TECH    600
# 20595         3574 2000-02-03         Jeopardy!          IN 2 WORDS    500
# 42158         3489 1999-04-11         Jeopardy!  I WAS A TEENAGE...    100
#
#                                                 Question  \
# 18334  In this comedy Allen discovers that a hooker p...
# 21052  Hsing-Hsing & Ling-Ling, 2 of these animals at...
# 55007  This word for the block on which blacksmiths s...
# 20595  Abbreviated C.O., it's a person who refuses to...
# 42158  In 1979 at the age of 18, this Great One began...
#
#                          Answer
# 18334        "Mighty Aphrodite"
# 21052                    Pandas
# 55007                     Anvil
# 20595  a conscientious objector
# ...

# %%
df.shape
#It stayed the SAME SHAPE as before the cleaning
# Out:
# (90900, 7)

# %%
df.dtypes
#GREAT each column has the correct format
# Out:
# Show_Number             int64
# Air_Date       datetime64[ns]
# Round                  object
# Category               object
# Value                   int64
# Question               object
# Answer                 object
# dtype: object

# %% [markdown]
# # 5. Exporting the data

# %%
df.to_csv('Jeopardy_v1')
